# %% [markdown]
# ##### 43.	Employee Attrition Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Sample employee data

# %%
data = {
    'Department': ['HR', 'IT', 'Sales', 'IT', 'Sales'],
    'Salary': [30000, 60000, 45000, 65000, 40000],
    'Attrition': ['Yes', 'No', 'Yes', 'No', 'Yes']
}

df = pd.DataFrame(data)

# %% [markdown]
# ##### Bar chart

# %%
plt.figure()
sns.countplot(x='Department', hue='Attrition', data=df)
plt.title("Employee Attrition by Department")
plt.show()

# Higher attrition observed in Sales department
# Employees with lower salaries tend to leave more
# IT department shows lower attrition rate

# %% [markdown]
# ##### Box plot

# %%
plt.figure()
sns.boxplot(x='Attrition', y='Salary', data=df)
plt.title("Salary Distribution by Attrition")
plt.show()
